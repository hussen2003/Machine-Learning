# %% [markdown]
# Problem 1

# %%
import numpy as np
import matplotlib.pyplot as plt

number_of_classes_M = 2
number_of_features_F = 5
initial_weights = np.random.uniform(low=-1, high=1,
                                     size = (number_of_classes_M, number_of_features_F))

# %%
N = 1000
learning_rate = 0.00005
iteration = 50

#training data points
X = np.random.normal(loc=0, scale=1,size=(N, number_of_features_F))
y = np.random.choice([0,1], size=(N,1))

#true labels
t = np.zeros((N, number_of_classes_M))
t[np.arange(N), y.T] = 1

# %%
errors = []
accuracy = []

for _ in range(iteration):
    Y = np.dot(X, initial_weights.T)

    E = 0.5 * np.sum((Y-t )**2, axis = 1)
    errors.append(np.mean(E))

    accuracy.append(np.mean(np.argmax(Y, axis=1) == y.T))

    for k in range(number_of_classes_M):
        for j in range(number_of_features_F):
            initial_weights[k, j] -= learning_rate * np.sum((Y[:, k] - t[:, k])*X[:, j])


plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.plot(errors)
plt.title('total MSE')
plt.xlabel('Iterations')
plt.ylabel('error')

plt.subplot(1, 2, 2)
plt.plot(accuracy)
plt.title('Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.tight_layout()

# %% [markdown]
# Problem 2

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
number_of_feature = 13
number_of_units_in_hidden_layer = 100
#### load the BOSTON regression dataset
(x_train, y_train), (x_test, y_test) =  tf.keras.datasets.boston_housing.load_data(path="boston_housing.npz", test_split=0.2, seed=113)
#### pre-process the data
x_train -= np.mean(x_train)
x_train /= np.std(x_train)
x_test -= np.mean(x_test)
x_test /= np.std(x_test)

NN_regression_model = tf.keras.Sequential()
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu', input_shape=(13,)) # define layer
NN_regression_model.add(hidden_layer_1) # add layer
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu') # define layer
NN_regression_model.add(hidden_layer_2) # add layer
output_layer = layers.Dense(units=1, activation=None) # define layer (units = 1 for regression)
NN_regression_model.add(output_layer) # add layer

# %%
# Define your optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
NN_regression_model.compile(optimizer=optimizer, loss='mse')

train_errors = []
test_errors = []

for epoch in range(500):
    # Train for one epoch
    NN_regression_model.fit(x_train, y_train, epochs=1, batch_size = 1, verbose=0)
    
    # Evaluate and store errors every 10 epochs
    if epoch % 10 == 0:
        train_error_mse = NN_regression_model.evaluate(x_train, y_train, verbose=0)
        test_error_mse = NN_regression_model.evaluate(x_test, y_test, verbose=0)
        train_errors.append(train_error_mse)
        test_errors.append(test_error_mse)
        print(f"After epoch {epoch}: MSE on training data = {train_error_mse} ; MSE of testing data = {test_error_mse}")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(range(0, 500, 10), train_errors, label='Training Error')
plt.plot(range(0, 500, 10), test_errors, label='Testing Error')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# After epoch 0: MSE on training data = 66.1810073852539 ; MSE of testing data = 63.62156295776367
# After epoch 10: MSE on training data = 54.3676872253418 ; MSE of testing data = 54.7586555480957
# After epoch 20: MSE on training data = 45.395687103271484 ; MSE of testing data = 48.516212463378906
# After epoch 30: MSE on training data = 42.785118103027344 ; MSE of testing data = 48.24504852294922
# After epoch 40: MSE on training data = 29.662506103515625 ; MSE of testing data = 34.499019622802734
# After epoch 50: MSE on training data = 30.453197479248047 ; MSE of testing data = 36.4376106262207
# After epoch 60: MSE on training data = 23.139333724975586 ; MSE of testing data = 31.74889373779297
# After epoch 70: MSE on training data = 20.1579532623291 ; MSE of testing data = 30.55465316772461
# After epoch 80: MSE on training data = 16.837371826171875 ; MSE of testing data = 29.504514694213867
# After epoch 90: MSE on training data = 20.150867462158203 ; MSE of testing data = 33.17271041870117
# After epoch 100: MSE on training data = 15.478618621826172 ; MSE of testing data = 32.699588775634766
# After epoch 110: MSE on training data = 17.09273910522461 ; MSE of testing data = 29.642276763916016
# After epoch 120: MSE on training data = 18.045108795166016 ; MSE of testing data = 35.613033294677734
# After epoch 130: MSE on training data = 14.185859680175781 ; MSE of testing data = 28.96377182006836
# After epoch 140: MSE on training data = 29.44652557373047 ; MSE of testing data = 38.864524841308594
# After epoch 150: MSE on training data = 18.927406311035156 ; MSE of testing data = 35.14201736450195
# After epoch 160: MSE on training data = 17.22593116760254 ; MSE of testing data = 30.40423011779785
# After epoch 170: MSE on training data = 31.674394607543945 ; MSE of testing data = 50.527950286865234
# After epoch 180: MSE on training data = 15.04138469696045 ; MSE of testing data = 28.852190017700195
# After epoch 190: MSE on training data = 12.863643646240234 ; MSE of testing data = 29.569307327270508
# After epoch 200: MSE on training data = 15.784937858581543 ; MSE of testing data = 31.31638526916504
# After epoch 210: MSE on training data = 19.937265396118164 ; MSE of testing data = 33.808658599853516
# After epoch 220: MSE on training data = 15.104050636291504 ; MSE of testing data = 28.885555267333984
# After epoch 230: MSE on training data = 24.06825065612793 ; MSE of testing data = 34.304012298583984
# After epoch 240: MSE on training data = 12.949483871459961 ; MSE of testing data = 28.9482421875
# After epoch 250: MSE on training data = 12.428797721862793 ; MSE of testing data = 26.949474334716797
# After epoch 260: MSE on training data = 17.201702117919922 ; MSE of testing data = 31.33831214904785
# After epoch 270: MSE on training data = 12.564582824707031 ; MSE of testing data = 28.008655548095703
# After epoch 280: MSE on training data = 13.974030494689941 ; MSE of testing data = 27.559223175048828
# After epoch 290: MSE on training data = 17.379648208618164 ; MSE of testing data = 27.494871139526367
# After epoch 300: MSE on training data = 11.507140159606934 ; MSE of testing data = 26.680936813354492
# After epoch 310: MSE on training data = 10.901409149169922 ; MSE of testing data = 28.342193603515625
# After epoch 320: MSE on training data = 12.665206909179688 ; MSE of testing data = 26.435102462768555
# After epoch 330: MSE on training data = 11.23226261138916 ; MSE of testing data = 28.197418212890625
# After epoch 340: MSE on training data = 11.344505310058594 ; MSE of testing data = 27.238666534423828
# After epoch 350: MSE on training data = 14.916394233703613 ; MSE of testing data = 32.13484573364258
# After epoch 360: MSE on training data = 11.144001960754395 ; MSE of testing data = 25.954647064208984
# After epoch 370: MSE on training data = 12.32986068725586 ; MSE of testing data = 27.214298248291016
# After epoch 380: MSE on training data = 22.51473617553711 ; MSE of testing data = 43.04033279418945
# After epoch 390: MSE on training data = 13.36435604095459 ; MSE of testing data = 30.3922061920166
# After epoch 400: MSE on training data = 10.976372718811035 ; MSE of testing data = 28.909351348876953
# After epoch 410: MSE on training data = 10.223243713378906 ; MSE of testing data = 26.34223175048828
# After epoch 420: MSE on training data = 10.85522174835205 ; MSE of testing data = 27.786266326904297
# After epoch 430: MSE on training data = 16.770376205444336 ; MSE of testing data = 29.810836791992188
# After epoch 440: MSE on training data = 12.555731773376465 ; MSE of testing data = 30.1716251373291
# After epoch 450: MSE on training data = 11.333075523376465 ; MSE of testing data = 27.865785598754883
# After epoch 460: MSE on training data = 10.567764282226562 ; MSE of testing data = 27.95580291748047
# After epoch 470: MSE on training data = 20.49041175842285 ; MSE of testing data = 37.10313034057617
# After epoch 480: MSE on training data = 11.05371379852295 ; MSE of testing data = 28.05413246154785
# After epoch 490: MSE on training data = 10.929389953613281 ; MSE of testing data = 29.205501556396484

# %% [markdown]
# Problem 3

# %%
number_of_features = 28*28
#### load the MNIST dataset
(x_train, y_train),(x_test, y_test)=tf.keras.datasets.mnist.load_data()
x_train,x_test=x_train.astype('float32'),x_test.astype('float32')
# normalize and vectorize the data
x_train /= 255
x_test /= 255
x_train,x_test= x_train.reshape(60000,784,1),x_test.reshape(10000,784,1)
# one-hot encoding (OHE)
y_train_OHE = []
for label in y_train:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_train_OHE.append(all_zero_temp)
y_train_OHE = np.asarray(y_train_OHE)
y_test_OHE = []
for label in y_test:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_test_OHE.append(all_zero_temp)
y_test_OHE = np.asarray(y_test_OHE)

# %%
NN_classification_model = tf.keras.Sequential()
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu', input_shape=(number_of_features,)) # define layer
NN_classification_model.add(hidden_layer_1) # add layer
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu') # define layer
NN_classification_model.add(hidden_layer_2) # add layer
output_layer = layers.Dense(units=10, activation='softmax') # define layer (units = 10 for classification)
NN_classification_model.add(output_layer) # add layer

# Compile the model
NN_classification_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
NN_classification_model.fit(x_train, y_train_OHE, epochs=100, batch_size=100)

# Evaluate the model
train_accuracy = NN_classification_model.evaluate(x_train, y_train_OHE)[1]
test_accuracy = NN_classification_model.evaluate(x_test, y_test_OHE)[1]

print("Accuracy on training data = {} ; Accuracy on testing data = {}".format(train_accuracy, test_accuracy))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.3210 - accuracy: 0.9083
# Epoch 2/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1276 - accuracy: 0.9626
# Epoch 3/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0908 - accuracy: 0.9729
# Epoch 4/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0695 - accuracy: 0.9783
# Epoch 5/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0560 - accuracy: 0.9828
# Epoch 6/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0441 - accuracy: 0.9867
# Epoch 7/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0384 - accuracy: 0.9881
# Epoch 8/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0309 - accuracy: 0.9903
# Epoch 9/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0268 - accuracy: 0.9916
# Epoch 10/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0224 - accuracy: 0.9931
# Epoch 11/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0188 - accuracy: 0.9942
# Epoch 12/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9947
# Epoch 13/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0149 - accuracy: 0.9953
# Epoch 14/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0150 - accuracy: 0.9953
# Epoch 15/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0124 - accuracy: 0.9960
# Epoch 16/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0101 - accuracy: 0.9969
# Epoch 17/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0084 - accuracy: 0.9976
# Epoch 18/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0092 - accuracy: 0.9969
# Epoch 19/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 20/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0102 - accuracy: 0.9967
# Epoch 21/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0070 - accuracy: 0.9977
# Epoch 22/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0061 - accuracy: 0.9982
# Epoch 23/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0098 - accuracy: 0.9966
# Epoch 24/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0069 - accuracy: 0.9978
# Epoch 25/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 26/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0097 - accuracy: 0.9968
# Epoch 27/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 28/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0109 - accuracy: 0.9963
# Epoch 29/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 30/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 31/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0063 - accuracy: 0.9980
# Epoch 32/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 33/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0066 - accuracy: 0.9977
# Epoch 34/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 35/100
# 600/600 [==============================] - 1s 1ms/step - loss: 7.5832e-04 - accuracy: 0.9998
# Epoch 36/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0083 - accuracy: 0.9976
# Epoch 37/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0102 - accuracy: 0.9966
# Epoch 38/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 39/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 40/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 41/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0083 - accuracy: 0.9974
# Epoch 42/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 43/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 44/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 45/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0086 - accuracy: 0.9976
# Epoch 46/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0064 - accuracy: 0.9980
# Epoch 47/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 48/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 49/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 50/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 51/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0061 - accuracy: 0.9979
# Epoch 52/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 53/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 54/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0060 - accuracy: 0.9981
# Epoch 55/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 56/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 57/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 58/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 59/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 60/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0050 - accuracy: 0.9985
# Epoch 61/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 62/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 63/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 64/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 65/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 66/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0073 - accuracy: 0.9978
# Epoch 67/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 68/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 69/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 70/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 71/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 72/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 73/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 74/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 75/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 76/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 77/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 78/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 79/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 80/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0024 - accuracy: 0.9994
# Epoch 81/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 82/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0058 - accuracy: 0.9982
# Epoch 83/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 84/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 85/100
# 600/600 [==============================] - 1s 1ms/step - loss: 2.4410e-04 - accuracy: 0.9999
# Epoch 86/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 87/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 88/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 89/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 90/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 91/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0060 - accuracy: 0.9983
# Epoch 92/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 93/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 94/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 95/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 96/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 97/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 98/100
# 600/600 [==============================] - 1s 1ms/step - loss: 6.2828e-04 - accuracy: 0.9998
# Epoch 99/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 100/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0054 - accuracy: 0.9985
# 1875/1875 [==============================] - 2s 865us/step - loss: 0.0023 - accuracy: 0.9993
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9805
# Accuracy on training data = 0.9993333220481873 ; Accuracy on testing data = 0.9804999828338623

# %% [markdown]
# Problem 4

# %%
number_of_features = 28*28
number_of_units_in_hidden_layer = 100
#### load the MNIST dataset
(x_train, y_train), (x_test, y_test)=tf.keras.datasets.fashion_mnist.load_data()
#### building the input vector from the 28x28 pixels
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# normalizing the data
x_train /= 255
x_test /= 255
# one-hot encoding (OHE)
y_train_OHE = []
for label in y_train:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_train_OHE.append(all_zero_temp)
y_train_OHE = np.asarray(y_train_OHE)
y_test_OHE = []
for label in y_test:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_test_OHE.append(all_zero_temp)
y_test_OHE = np.asarray(y_test_OHE)
#### Construct the NN classification model
NN_classification_model = tf.keras.Sequential()
# define conv layer
Conv2d_layer = layers.Conv2D(128, kernel_size=(3,3), strides=(1,1),
padding='valid', activation='relu', input_shape=(28,28,1))
NN_classification_model.add(Conv2d_layer)# add layer
# define max pooling layer
MaxPool_layer = layers.MaxPool2D(pool_size=(4,4))
NN_classification_model.add(MaxPool_layer)#add layer
# define flatten layer (reshaping from tensor to vector)
flatten_layer = layers.Flatten()
NN_classification_model.add(flatten_layer) #add flatten layer

# %%
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu')
NN_classification_model.add(hidden_layer_1)
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu')
NN_classification_model.add(hidden_layer_2)

output_layer = layers.Dense(units=10, activation='softmax')
NN_classification_model.add(output_layer)

NN_classification_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

NN_classification_model.fit(x_train, y_train_OHE, epochs=100, batch_size=100)

train_accuracy = NN_classification_model.evaluate(x_train, y_train_OHE)[1]
test_accuracy = NN_classification_model.evaluate(x_test, y_test_OHE)[1]

print("Accuracy on training data = {} ; Accuracy on testing data = {}".format(train_accuracy, test_accuracy))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.5134 - accuracy: 0.8173
# Epoch 2/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.3378 - accuracy: 0.8790
# Epoch 3/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2972 - accuracy: 0.8917
# Epoch 4/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2689 - accuracy: 0.9016
# Epoch 5/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.2494 - accuracy: 0.9073
# Epoch 6/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2326 - accuracy: 0.9135
# Epoch 7/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2172 - accuracy: 0.9194
# Epoch 8/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2010 - accuracy: 0.9255
# Epoch 9/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1918 - accuracy: 0.9279
# Epoch 10/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1801 - accuracy: 0.9325
# Epoch 11/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1692 - accuracy: 0.9368
# Epoch 12/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1601 - accuracy: 0.9397
# Epoch 13/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1498 - accuracy: 0.9433
# Epoch 14/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1429 - accuracy: 0.9457
# Epoch 15/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1331 - accuracy: 0.9485
# Epoch 16/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1243 - accuracy: 0.9533
# Epoch 17/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1157 - accuracy: 0.9558
# Epoch 18/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1090 - accuracy: 0.9585
# Epoch 19/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1042 - accuracy: 0.9606
# Epoch 20/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0923 - accuracy: 0.9655
# Epoch 21/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0879 - accuracy: 0.9665
# Epoch 22/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0838 - accuracy: 0.9687
# Epoch 23/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0755 - accuracy: 0.9724
# Epoch 24/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0739 - accuracy: 0.9725
# Epoch 25/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0705 - accuracy: 0.9731
# Epoch 26/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0642 - accuracy: 0.9758
# Epoch 27/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0611 - accuracy: 0.9775
# Epoch 28/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0542 - accuracy: 0.9801
# Epoch 29/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0532 - accuracy: 0.9799
# Epoch 30/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.