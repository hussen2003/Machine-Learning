# %% [markdown]
# 1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = pd.read_csv("Boston.csv", index_col= 0)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 1       15.3  396.90   4.98  24.0
# 2       17.8  396.90   9.14  21.6
# 3       17.8  392.83   4.03  34.7
# 4       18.7  394.63   2.94  33.4
# 5       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 502     21.0  391.99   9.67  22.4
# 503     21.0  396.90   9.08  20.6
# 504     21.0  396.90   5.64  23.9
# 505     21.0  393.45   6.48  22.0
# 506     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# Use a correlation and regression test to find which of the variables is the best predictor of NOX(nitric oxides concentration). For that model, provide the regression plot and equation. In generating the line, pick 100 test points equally-spaced from the min to the max of the predictor and use the predict method to obtain the model predictions (as we did in class).

# %%
df.corr() #check all possible correlation between columns
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# black   -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black    0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# from this we can see indus is the best variable predictor of nox with a Correlation coefficient of 0.763651

# %%
x = df.indus #predictor
y = df.nox #response 
x = sm.add_constant(x)
print(x)

lr_model = sm.OLS(y, x).fit()   
print(lr_model.summary())
# Out:
#      const  indus
# 1      1.0   2.31
# 2      1.0   7.07
# 3      1.0   7.07
# 4      1.0   2.18
# 5      1.0   2.18
# ..     ...    ...
# 502    1.0  11.93
# 503    1.0  11.93
# 504    1.0  11.93
# 505    1.0  11.93
# 506    1.0  11.93
#
# [506 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    nox   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     705.1
# Date:                Sun, 08 Oct 2023   Prob (F-statistic):           7.91e-98
# Time:                        19:00:34   Log-Likelihood:                 594.45
# No. Observations:                 506   AIC:                            -1185.
# Df Residuals:                     504   BIC:                            -1176.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4110      0.006     64.710      0.000       0.399       0.424
# indus          0.0129      0.000     26.554      0.000       0.012       0.014
# ==============================================================================
# Omnibus:                       35.023   Durbin-Watson:                   0.279
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.995
# Skew:                           0.548   Prob(JB):                     3.78e-11
# Kurtosis:                       4.038   Cond. No.                         25.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_prime = np.linspace(x.indus.min(), x.indus.max(), 100)
X_prime = sm.add_constant(X_prime)  # Add a constant as we did before

# Now we calculate the predicted values
y_hat = lr_model.predict(X_prime)


plt.scatter(x.indus, y)  # Plot the raw data
plt.xlabel("indus")
plt.ylabel("nox")
# Add the regression line, colored in red
plt.plot(X_prime[:, 1], y_hat, 'red', alpha=0.8)

# %% [markdown]
# Do the same to find the best predictor of MEDV (median home value). For that model, provide the regression plot and equation as in the previous part.

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# black   -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black    0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# best predicctor for medv is rm with a 0.695 corelation.

# %%
x = df.rm #predictor
y = df.medv #response 
x = sm.add_constant(x)
print(x)

lr_model = sm.OLS(y, x).fit()   
print(lr_model.summary())
# Out:
#      const     rm
# 1      1.0  6.575
# 2      1.0  6.421
# 3      1.0  7.185
# 4      1.0  6.998
# 5      1.0  7.147
# ..     ...    ...
# 502    1.0  6.593
# 503    1.0  6.120
# 504    1.0  6.976
# 505    1.0  6.794
# 506    1.0  6.030
#
# [506 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   medv   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Sun, 08 Oct 2023   Prob (F-statistic):           2.49e-74
# Time:                        19:00:38   Log-Likelihood:                -1673.1
# No. Observations:                 506   AIC:                             3350.
# Df Residuals:                     504   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6706      2.650    -13.084      0.000     -39.877     -29.465
# rm             9.1021      0.419     21.722      0.000       8.279       9.925
# ==============================================================================
# Omnibus:                      102.585   Durbin-Watson:                   0.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              612.449
# Skew:                           0.726   Prob(JB):                    1.02e-133
# Kurtosis:                       8.190   Cond. No.                         58.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_prime = np.linspace(x.rm.min(), x.rm.max(), 100)
X_prime = sm.add_constant(X_prime)  # Add a constant as we did before

# Now we calculate the predicted values
y_hat = lr_model.predict(X_prime)


plt.scatter(x.rm, y)  # Plot the raw data
plt.xlabel("rm")
plt.ylabel("medv")
# Add the regression line, colored in red
plt.plot(X_prime[:, 1], y_hat, 'red', alpha=0.8)

# %% [markdown]
# 2)

# %%
x = np.linspace(0, 1, 10)  # N = 10
# with mean 0 and variance 0.2 from a normal (Gaussian) distribution
#scale is standart diviation must sqrt
y = np.sin(2*np.pi*x) + np.random.normal(loc=0, scale=np.sqrt(0.2), size=x.size)

x_test = np.linspace(0, 1, 100)
y_test = np.sin(2 * np.pi * x_test)

plt.scatter(x, y, color="b", s=10, label="training data")

plt.plot(x_test, y_test, c="r", linestyle=":", label="$\sin(2\pi x)$")
p(x_test)

for i, M in enumerate([1, 3, 9]):
    # Fit a polynomial of order M
    w = np.polyfit(x, y, M)
    p = np.poly1d(w)

    #plt.subplot(1, 3, i+1)
    
    label = f'model order {M}'
    # Plot the learned model
    plt.plot(x_test, p(x_test), label=label)
    plt.ylim(-1.5, 1.5)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 12
#       9 plt.scatter(x, y, color="b", s=10, label="training data")
#      11 plt.plot(x_test, y_test, c="r", linestyle=":", label="$\sin(2\pi x)$")
# ---> 12 p(x_test)
#      14 for i, M in enumerate([1, 3, 9]):
#      15     # Fit a polynomial of order M
#      16     w = np.polyfit(x, y, M)
#
# NameError: name 'p' is not defined

# %% [markdown]
# In this example a M of 9 result in overfitting, it would perfrom really well on trained data but perform poorly on unseen data. Since the size of the model is 10 and the order is 9 the closer the order gets to the size the more overfitting could be an issue.

# %%
x = np.linspace(0, 1, 50)  # N = 50
# with mean 0 and variance 0.2 from a normal (Gaussian) distribution
y = np.sin(2*np.pi*x) + np.random.normal(loc=0,
                                         scale=np.sqrt(0.2), size=x.size)

x_test = np.linspace(0, 1, 100)
y_test = np.sin(2 * np.pi * x_test)

plt.scatter(x, y, color="b", s=10, label="training data")

plt.plot(x_test, y_test, c="r", linestyle=":", label="$\sin(2\pi x)$")
p(x_test)

for i, M in enumerate([1, 3, 9]):
    # Fit a polynomial of order M
    w = np.polyfit(x, y, M)
    p = np.poly1d(w)

    #plt.subplot(1, 3, i+1)
    
    label = f'model order {M}'
    # Plot the learned model
    plt.plot(x_test, p(x_test), label=label)
    plt.ylim(-1.5, 1.5)
    
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 12
#       9 plt.scatter(x, y, color="b", s=10, label="training data")
#      11 plt.plot(x_test, y_test, c="r", linestyle=":", label="$\sin(2\pi x)$")
# ---> 12 p(x_test)
#      14 for i, M in enumerate([1, 3, 9]):
#      15     # Fit a polynomial of order M
#      16     w = np.polyfit(x, y, M)
#
# NameError: name 'p' is not defined

# %% [markdown]
# As the training model size(N) gets larger it does not suffer from overfiting as much with the same M of 9.

# %%
x = np.linspace(0, 1, 10)  # N = 10
# with mean 0 and variance 0.2 from a normal (Gaussian) distribution
y = np.sin(2*np.pi*x) + np.random.normal(loc=0, scale=np.sqrt(0.2), size=x.size)

x_test = np.linspace(0, 1, 100)
y_test = np.sin(2 * np.pi * x_test)

errors_train = []
errors_test = []

M = np.arange(1, 16)

for degree in M:
# Fit a polynomial of order M
    w = np.polyfit(x, y, degree)
    p = np.poly1d(w)

    E_w_train = 0.5 * np.sum((p(x) - y)**2)
    ERMS_train = np.sqrt((2 * E_w_train)/x.size)

    E_w_test = 0.5 * np.sum((p(x_test) - y_test)**2)
    ERMS_test = np.sqrt((2 * E_w_test)/x_test.size)

    errors_train.append(ERMS_train)
    errors_test.append(ERMS_test)

# Plot the learned model

plt.plot(M, errors_train, label='Training Error', marker='o')
plt.plot(M, errors_test, label='Testing Error', marker='o')
#plt.xlabel("Degree M")
#plt.ylabel("RMS Error")
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# From this we can see as M increases both the training error and testing error decreases.
# But past a certain point increasing M too much leads to overfitting in the testing data so we see the errors increase.

# %%
x = np.linspace(0, 1, 10)  # N = 10
y = y = np.sin(2*np.pi*x) + np.random.normal(loc=0,
                                             scale=np.sqrt(0.2), size=x.size)

for M in range(1, 11):
    # Fit a polynomial of order M
    w = np.polyfit(x, y, M)
    print("Optimal weights for M =",M, ":", w)
    print("Max magnitude:", np.max(abs(w)))
    print("Min magnitude:", np.min(abs(w)))
# Out:
# Optimal weights for M = 1 : [-0.4256446   0.09749507]
# Max magnitude: 0.42564459519501024
# Min magnitude: 0.09749506934027509
# Optimal weights for M = 2 : [-0.39068317 -0.03496142  0.03961608]
# Max magnitude: 0.3906831720798289
# Min magnitude: 0.03496142311518108
# Optimal weights for M = 3 : [ 19.75676888 -30.0258365   11.20932309  -0.64333395]
# Max magnitude: 30.02583649654534
# Min magnitude: 0.6433339545769367
# Optimal weights for M = 4 : [-14.20989663  48.17656213 -47.74434957  14.71793954  -0.73689706]
# Max magnitude: 48.176562134215985
# Min magnitude: 0.7368970599307902
# Optimal weights for M = 5 : [-50.21419753 111.3255972  -61.34411561  -8.99882679  10.06975238
#   -0.68587415]
# Max magnitude: 111.32559720416289
# Min magnitude: 0.6858741492648274
# Optimal weights for M = 6 : [ 7.63807318e+02 -2.34163615e+03  2.68735364e+03 -1.39436362e+03
#   3.00710854e+02 -1.50338343e+01 -5.91800375e-01]
# Max magnitude: 2687.3536435416027
# Min magnitude: 0.5918003747795252
# Optimal weights for M = 7 : [ 1.98875970e+03 -6.19685162e+03  7.24992711e+03 -3.88990718e+03
#   9.31761534e+02 -9.15455282e+01  8.73815205e+00 -6.13782542e-01]
# Max magnitude: 7249.9271139472885
# Min magnitude: 0.6137825417348279
# Optimal weights for M = 8 : [ 6.71813988e+03 -2.48837998e+04  3.76949956e+04 -3.03716562e+04
#   1.41808518e+04 -3.85843690e+03  5.43542031e+02 -2.27541589e+01
#  -6.09382129e-01]
# Max magnitude: 37694.995570108316
# Min magnitude: 0.6093821286047306
# Optimal weights for M = 9 : [-9.48225362e+04  4.33419553e+05 -8.31391820e+05  8.69199806e+05
#  -5.38179633e+05  2.00575398e+05 -4.35348599e+04  4.94842747e+03
#  -2.13456222e+02 -6.07555387e-01]
# Max magnitude: 869199.8062480242
# Min magnitude: 0.6075553873712918
# Optimal weights for M = 10 : [-6.49321229e+04  2.29838078e+05 -2.63999545e+05  1.03208845e+04
#   2.43007120e+05 -2.42021460e+05  1.12155274e+05 -2.76146437e+04
#   3.39992953e+03 -1.52637114e+02 -6.07555387e-01]
# Max magnitude: 263999.54527458426
# Min magnitude: 0.6075553872447446
# C:\Users\husse\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# As the degree increases the magnitude of the weights increaseds as well, because higher dregree polynomials fit the data better. However too larges can lead to overfitting, methods such as regularization helps with this issue.

# %%
from sklearn.linear_model import Ridge
