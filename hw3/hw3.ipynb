# %% [markdown]
# Problem 1

# %%
import numpy as np
import matplotlib.pyplot as plt

number_of_classes_M = 2
number_of_features_F = 5
initial_weights = np.random.uniform(low=-1, high=1,
                                     size = (number_of_classes_M, number_of_features_F))

# %%
N = 1000
learning_rate = 0.00005
iteration = 50

#training data points
X = np.random.normal(loc=0, scale=1,size=(N, number_of_features_F))
y = np.random.choice([0,1], size=(N,1))

#true labels
t = np.zeros((N, number_of_classes_M))
t[np.arange(N), y.T] = 1

# %%
errors = []
accuracy = []

for _ in range(iteration):
    Y = np.dot(X, initial_weights.T)

    E = 0.5 * np.sum((Y-t )**2, axis = 1)
    errors.append(np.mean(E))

    accuracy.append(np.mean(np.argmax(Y, axis=1) == y.T))

    for k in range(number_of_classes_M):
        for j in range(number_of_features_F):
            initial_weights[k, j] -= learning_rate * np.sum((Y[:, k] - t[:, k])*X[:, j])


plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.plot(errors)
plt.title('total MSE')
plt.xlabel('Iterations')
plt.ylabel('error')

plt.subplot(1, 2, 2)
plt.plot(accuracy)
plt.title('Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.tight_layout()

# %% [markdown]
# Problem 2

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

number_of_feature = 13
number_of_units_in_hidden_layer = 100
#### load the BOSTON regression dataset
(x_train, y_train), (x_test, y_test) =  tf.keras.datasets.boston_housing.load_data(path="boston_housing.npz", test_split=0.2, seed=113)
#### pre-process the data
x_train -= np.mean(x_train)
x_train /= np.std(x_train)
x_test -= np.mean(x_test)
x_test /= np.std(x_test)

NN_regression_model = tf.keras.Sequential()
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu', input_shape=(13,)) # define layer
NN_regression_model.add(hidden_layer_1) # add layer
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu') # define layer
NN_regression_model.add(hidden_layer_2) # add layer
output_layer = layers.Dense(units=1, activation=None) # define layer (units = 1 for regression)
NN_regression_model.add(output_layer) # add layer

# %%
# Define your optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
NN_regression_model.compile(optimizer=optimizer, loss='mse')

train_errors = []
test_errors = []

for epoch in range(500):
    # Train for one epoch
    NN_regression_model.fit(x_train, y_train, epochs=1, batch_size = 1, verbose=0)
    
    # Evaluate and store errors every 10 epochs
    if epoch % 10 == 0:
        train_error_mse = NN_regression_model.evaluate(x_train, y_train, verbose=0)
        test_error_mse = NN_regression_model.evaluate(x_test, y_test, verbose=0)
        train_errors.append(train_error_mse)
        test_errors.append(test_error_mse)
        print(f"After epoch {epoch}: MSE on training data = {train_error_mse} ; MSE of testing data = {test_error_mse}")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(range(0, 500, 10), train_errors, label='Training Error')
plt.plot(range(0, 500, 10), test_errors, label='Testing Error')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# After epoch 0: MSE on training data = 66.06563568115234 ; MSE of testing data = 64.66558837890625
# After epoch 10: MSE on training data = 53.22732162475586 ; MSE of testing data = 54.05508804321289
# After epoch 20: MSE on training data = 49.95942306518555 ; MSE of testing data = 53.5505256652832
# After epoch 30: MSE on training data = 45.520015716552734 ; MSE of testing data = 46.936866760253906
# After epoch 40: MSE on training data = 35.50254821777344 ; MSE of testing data = 37.86884307861328
# After epoch 50: MSE on training data = 27.160093307495117 ; MSE of testing data = 33.7780647277832
# After epoch 60: MSE on training data = 24.314931869506836 ; MSE of testing data = 32.470027923583984
# After epoch 70: MSE on training data = 20.578369140625 ; MSE of testing data = 34.92255401611328
# After epoch 80: MSE on training data = 18.69499397277832 ; MSE of testing data = 32.62382125854492
# After epoch 90: MSE on training data = 15.855868339538574 ; MSE of testing data = 28.241504669189453
# After epoch 100: MSE on training data = 17.77031898498535 ; MSE of testing data = 33.79659652709961
# After epoch 110: MSE on training data = 22.99332618713379 ; MSE of testing data = 30.830810546875
# After epoch 120: MSE on training data = 21.157766342163086 ; MSE of testing data = 35.016109466552734
# After epoch 130: MSE on training data = 23.535968780517578 ; MSE of testing data = 39.11272430419922
# After epoch 140: MSE on training data = 76.610595703125 ; MSE of testing data = 98.57057189941406
# After epoch 150: MSE on training data = 41.93148422241211 ; MSE of testing data = 66.7354965209961
# After epoch 160: MSE on training data = 14.179970741271973 ; MSE of testing data = 28.018054962158203
# After epoch 170: MSE on training data = 22.229530334472656 ; MSE of testing data = 37.896114349365234
# After epoch 180: MSE on training data = 30.36692237854004 ; MSE of testing data = 42.09965133666992
# After epoch 190: MSE on training data = 19.607934951782227 ; MSE of testing data = 36.291542053222656
# After epoch 200: MSE on training data = 14.232956886291504 ; MSE of testing data = 32.510555267333984
# After epoch 210: MSE on training data = 20.294973373413086 ; MSE of testing data = 32.94930648803711
# After epoch 220: MSE on training data = 17.694541931152344 ; MSE of testing data = 30.562406539916992
# After epoch 230: MSE on training data = 13.463401794433594 ; MSE of testing data = 24.894956588745117
# After epoch 240: MSE on training data = 22.96642303466797 ; MSE of testing data = 33.182708740234375
# After epoch 250: MSE on training data = 12.120782852172852 ; MSE of testing data = 27.103696823120117
# After epoch 260: MSE on training data = 21.98657989501953 ; MSE of testing data = 31.034875869750977
# After epoch 270: MSE on training data = 17.446561813354492 ; MSE of testing data = 29.123064041137695
# After epoch 280: MSE on training data = 17.910076141357422 ; MSE of testing data = 32.181026458740234
# After epoch 290: MSE on training data = 15.694978713989258 ; MSE of testing data = 28.919462203979492
# After epoch 300: MSE on training data = 18.74029541015625 ; MSE of testing data = 38.27942657470703
# After epoch 310: MSE on training data = 15.737462997436523 ; MSE of testing data = 30.984485626220703
# After epoch 320: MSE on training data = 12.762922286987305 ; MSE of testing data = 26.677413940429688
# After epoch 330: MSE on training data = 11.196314811706543 ; MSE of testing data = 26.5706787109375
# After epoch 340: MSE on training data = 14.372273445129395 ; MSE of testing data = 25.333009719848633
# After epoch 350: MSE on training data = 20.10032081604004 ; MSE of testing data = 36.1910285949707
# After epoch 360: MSE on training data = 20.155536651611328 ; MSE of testing data = 39.59086227416992
# After epoch 370: MSE on training data = 26.96013069152832 ; MSE of testing data = 44.19815444946289
# After epoch 380: MSE on training data = 11.34216594696045 ; MSE of testing data = 26.546388626098633
# After epoch 390: MSE on training data = 13.60893726348877 ; MSE of testing data = 28.647686004638672
# After epoch 400: MSE on training data = 57.52909469604492 ; MSE of testing data = 75.0512466430664
# After epoch 410: MSE on training data = 30.64324951171875 ; MSE of testing data = 48.28578186035156
# After epoch 420: MSE on training data = 11.91160774230957 ; MSE of testing data = 27.967483520507812
# After epoch 430: MSE on training data = 75.56547546386719 ; MSE of testing data = 93.86418151855469
# After epoch 440: MSE on training data = 10.974481582641602 ; MSE of testing data = 26.274490356445312
# After epoch 450: MSE on training data = 10.811931610107422 ; MSE of testing data = 26.502716064453125
# After epoch 460: MSE on training data = 13.177481651306152 ; MSE of testing data = 27.045520782470703
# After epoch 470: MSE on training data = 21.861310958862305 ; MSE of testing data = 41.37449645996094
# After epoch 480: MSE on training data = 11.3307466506958 ; MSE of testing data = 24.826961517333984
# After epoch 490: MSE on training data = 15.517638206481934 ; MSE of testing data = 28.859960556030273

# %% [markdown]
# Problem 3

# %%
number_of_features = 28*28
#### load the MNIST dataset
(x_train, y_train),(x_test, y_test)=tf.keras.datasets.mnist.load_data()
x_train,x_test=x_train.astype('float32'),x_test.astype('float32')
# normalize and vectorize the data
x_train /= 255
x_test /= 255
x_train,x_test= x_train.reshape(60000,784,1),x_test.reshape(10000,784,1)
# one-hot encoding (OHE)
y_train_OHE = []
for label in y_train:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_train_OHE.append(all_zero_temp)
y_train_OHE = np.asarray(y_train_OHE)
y_test_OHE = []
for label in y_test:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_test_OHE.append(all_zero_temp)
y_test_OHE = np.asarray(y_test_OHE)

# %%
NN_classification_model = tf.keras.Sequential()
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu', input_shape=(number_of_features,)) # define layer
NN_classification_model.add(hidden_layer_1) # add layer
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu') # define layer
NN_classification_model.add(hidden_layer_2) # add layer
output_layer = layers.Dense(units=10, activation='softmax') # define layer (units = 10 for classification)
NN_classification_model.add(output_layer) # add layer

# Compile the model
NN_classification_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
NN_classification_model.fit(x_train, y_train_OHE, epochs=100, batch_size=100)

# Evaluate the model
train_accuracy = NN_classification_model.evaluate(x_train, y_train_OHE)[1]
test_accuracy = NN_classification_model.evaluate(x_test, y_test_OHE)[1]

print("Accuracy on training data = {} ; Accuracy on testing data = {}".format(train_accuracy, test_accuracy))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3178 - accuracy: 0.9092
# Epoch 2/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1296 - accuracy: 0.9618
# Epoch 3/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0893 - accuracy: 0.9733
# Epoch 4/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0690 - accuracy: 0.9789
# Epoch 5/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0548 - accuracy: 0.9831
# Epoch 6/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0456 - accuracy: 0.9855
# Epoch 7/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0359 - accuracy: 0.9891
# Epoch 8/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0316 - accuracy: 0.9902
# Epoch 9/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.9919
# Epoch 10/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0211 - accuracy: 0.9934
# Epoch 11/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9941
# Epoch 12/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0167 - accuracy: 0.9947
# Epoch 13/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0146 - accuracy: 0.9951
# Epoch 14/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0156 - accuracy: 0.9948
# Epoch 15/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0111 - accuracy: 0.9962
# Epoch 16/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0102 - accuracy: 0.9966
# Epoch 17/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0091 - accuracy: 0.9970
# Epoch 18/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0117 - accuracy: 0.9962
# Epoch 19/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 20/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 21/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0071 - accuracy: 0.9977
# Epoch 22/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 23/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 24/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 25/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0079 - accuracy: 0.9974
# Epoch 26/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0076 - accuracy: 0.9975
# Epoch 27/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 28/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 29/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0087 - accuracy: 0.9969
# Epoch 30/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0074 - accuracy: 0.9976
# Epoch 31/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 32/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0042 - accuracy: 0.9985
# Epoch 33/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 34/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 35/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 36/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 37/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.9980
# Epoch 38/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9971
# Epoch 39/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 40/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 41/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 42/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 43/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 44/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 45/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 46/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 47/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9983
# Epoch 48/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 49/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0072 - accuracy: 0.9979
# Epoch 50/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 51/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 52/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0065 - accuracy: 0.9977
# Epoch 53/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 54/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 55/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 56/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 57/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 58/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 59/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 60/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 61/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 62/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 63/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 64/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 65/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 66/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 67/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 68/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 69/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 70/100
# 600/600 [==============================] - 2s 2ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 71/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 72/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9988
# Epoch 73/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 74/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 75/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 76/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 77/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 78/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 79/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 80/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 81/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 82/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 83/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 84/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 85/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 86/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 87/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0044 - accuracy: 0.9989
# Epoch 88/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 89/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 90/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 91/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 92/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 93/100
# 600/600 [==============================] - 1s 2ms/step - loss: 2.5863e-04 - accuracy: 0.9999
# Epoch 94/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 95/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0066 - accuracy: 0.9984
# Epoch 96/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 97/100
# 600/600 [==============================] - 1s 2ms/step - loss: 7.6305e-04 - accuracy: 0.9998
# Epoch 98/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 99/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 100/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 0.9997
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2028 - accuracy: 0.9784
# Accuracy on training data = 0.9996500015258789 ; Accuracy on testing data = 0.9783999919891357

# %% [markdown]
# Problem 4

# %%
number_of_features = 28*28
number_of_units_in_hidden_layer = 100
#### load the MNIST dataset
(x_train, y_train), (x_test, y_test)=tf.keras.datasets.fashion_mnist.load_data()
#### building the input vector from the 28x28 pixels
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# normalizing the data
x_train /= 255
x_test /= 255
# one-hot encoding (OHE)
y_train_OHE = []
for label in y_train:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_train_OHE.append(all_zero_temp)
y_train_OHE = np.asarray(y_train_OHE)
y_test_OHE = []
for label in y_test:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_test_OHE.append(all_zero_temp)
y_test_OHE = np.asarray(y_test_OHE)
#### Construct the NN classification model
NN_classification_model = tf.keras.Sequential()
# define conv layer
Conv2d_layer = layers.Conv2D(128, kernel_size=(3,3), strides=(1,1),
padding='valid', activation='relu', input_shape=(28,28,1))
NN_classification_model.add(Conv2d_layer)# add layer
# define max pooling layer
MaxPool_layer = layers.MaxPool2D(pool_size=(4,4))
NN_classification_model.add(MaxPool_layer)#add layer
# define flatten layer (reshaping from tensor to vector)
flatten_layer = layers.Flatten()
NN_classification_model.add(flatten_layer) #add flatten layer

# %%
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu')
NN_classification_model.add(hidden_layer_1)
hidden_layer_2 = layers.Dense(units=number_of_units_in_hidden_layer, activation='relu')
NN_classification_model.add(hidden_layer_2)

output_layer = layers.Dense(units=10, activation='softmax')
NN_classification_model.add(output_layer)

NN_classification_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

NN_classification_model.fit(x_train, y_train_OHE, epochs=100, batch_size=100)

train_accuracy = NN_classification_model.evaluate(x_train, y_train_OHE)[1]
test_accuracy = NN_classification_model.evaluate(x_test, y_test_OHE)[1]

print("Accuracy on training data = {} ; Accuracy on testing data = {}".format(train_accuracy, test_accuracy))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 7s 5ms/step - loss: 0.5095 - accuracy: 0.8172
# Epoch 2/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.3387 - accuracy: 0.8786
# Epoch 3/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2947 - accuracy: 0.8917
# Epoch 4/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2700 - accuracy: 0.8990
# Epoch 5/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2506 - accuracy: 0.9069
# Epoch 6/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2339 - accuracy: 0.9141
# Epoch 7/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2184 - accuracy: 0.9190
# Epoch 8/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2051 - accuracy: 0.9235
# Epoch 9/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1919 - accuracy: 0.9274
# Epoch 10/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1813 - accuracy: 0.9317
# Epoch 11/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1672 - accuracy: 0.9369
# Epoch 12/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1589 - accuracy: 0.9406
# Epoch 13/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1494 - accuracy: 0.9431
# Epoch 14/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1399 - accuracy: 0.9471
# Epoch 15/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1287 - accuracy: 0.9513
# Epoch 16/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1207 - accuracy: 0.9543
# Epoch 17/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1122 - accuracy: 0.9573
# Epoch 18/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1063 - accuracy: 0.9598
# Epoch 19/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1004 - accuracy: 0.9619
# Epoch 20/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0917 - accuracy: 0.9656
# Epoch 21/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0854 - accuracy: 0.9676
# Epoch 22/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0794 - accuracy: 0.9696
# Epoch 23/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0714 - accuracy: 0.9731
# Epoch 24/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0689 - accuracy: 0.9739
# Epoch 25/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0647 - accuracy: 0.9760
# Epoch 26/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0582 - accuracy: 0.9783
# Epoch 27/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0549 - accuracy: 0.9796
# Epoch 28/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0523 - accuracy: 0.9807
# Epoch 29/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0457 - accuracy: 0.9828
# Epoch 30/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0446 - accuracy: 0.9837
# Epoch 31/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0434 - accuracy: 0.9837
# Epoch 32/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0360 - accuracy: 0.9865
# Epoch 33/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0378 - accuracy: 0.9859
# Epoch 34/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0409 - accuracy: 0.9855
# Epoch 35/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0322 - accuracy: 0.9883
# Epoch 36/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0286 - accuracy: 0.9898
# Epoch 37/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0303 - accuracy: 0.9888
# Epoch 38/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0366 - accuracy: 0.9865
# Epoch 39/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0270 - accuracy: 0.9903
# Epoch 40/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0341 - accuracy: 0.9875
# Epoch 41/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0219 - accuracy: 0.9924
# Epoch 42/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0254 - accuracy: 0.9912
# Epoch 43/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0254 - accuracy: 0.9911
# Epoch 44/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0230 - accuracy: 0.9918
# Epoch 45/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0258 - accuracy: 0.9907
# Epoch 46/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0259 - accuracy: 0.9902
# Epoch 47/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0294 - accuracy: 0.9897
# Epoch 48/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0222 - accuracy: 0.9919
# Epoch 49/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0141 - accuracy: 0.9955
# Epoch 50/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0245 - accuracy: 0.9914
# Epoch 51/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0198 - accuracy: 0.9930
# Epoch 52/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0174 - accuracy: 0.9942
# Epoch 53/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0266 - accuracy: 0.9906
# Epoch 54/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0134 - accuracy: 0.9955
# Epoch 55/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0193 - accuracy: 0.9932
# Epoch 56/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0181 - accuracy: 0.9932
# Epoch 57/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0275 - accuracy: 0.9905
# Epoch 58/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0092 - accuracy: 0.9971
# Epoch 59/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0244 - accuracy: 0.9915
# Epoch 60/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0129 - accuracy: 0.9954
# Epoch 61/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0182 - accuracy: 0.9941
# Epoch 62/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0114 - accuracy: 0.9962
# Epoch 63/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0210 - accuracy: 0.9928
# Epoch 64/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0154 - accuracy: 0.9942
# Epoch 65/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0162 - accuracy: 0.9946
# Epoch 66/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0199 - accuracy: 0.9932
# Epoch 67/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 68/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0210 - accuracy: 0.9928
# Epoch 69/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0177 - accuracy: 0.9944
# Epoch 70/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0126 - accuracy: 0.9956
# Epoch 71/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0108 - accuracy: 0.9965
# Epoch 72/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0180 - accuracy: 0.9940
# Epoch 73/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0146 - accuracy: 0.9954
# Epoch 74/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0143 - accuracy: 0.9955
# Epoch 75/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0196 - accuracy: 0.9934
# Epoch 76/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0147 - accuracy: 0.9950
# Epoch 77/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0122 - accuracy: 0.9963
# Epoch 78/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0140 - accuracy: 0.9951
# Epoch 79/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0179 - accuracy: 0.9937
# Epoch 80/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0150 - accuracy: 0.9953
# Epoch 81/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0116 - accuracy: 0.9963
# Epoch 82/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0137 - accuracy: 0.9953
# Epoch 83/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0097 - accuracy: 0.9965
# Epoch 84/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 85/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0118 - accuracy: 0.9960
# Epoch 86/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0112 - accuracy: 0.9963
# Epoch 87/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0144 - accuracy: 0.9952
# Epoch 88/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0145 - accuracy: 0.9950
# Epoch 89/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0186 - accuracy: 0.9941
# Epoch 90/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0080 - accuracy: 0.9975
# Epoch 91/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0107 - accuracy: 0.9966
# Epoch 92/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0169 - accuracy: 0.9944
# Epoch 93/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0095 - accuracy: 0.9968
# Epoch 94/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0158 - accuracy: 0.9952
# Epoch 95/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0092 - accuracy: 0.9971
# Epoch 96/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0099 - accuracy: 0.9966
# Epoch 97/100
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0093 - accuracy: 0.9970
# Epoch 98/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0150 - accuracy: 0.9952
# Epoch 99/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0161 - accuracy: 0.9948
# Epoch 100/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0080 - accuracy: 0.9974
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0075 - accuracy: 0.9973
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9112 - accuracy: 0.9093
# Accuracy on training data = 0.9973333477973938 ; Accuracy on testing data = 0.9093000292778015
